# %%
import pandas as pd

# %%
df = pd.DataFrame({'ten':[10,20,30,40,50],
                   'one':[1,-2,-4,5,6]})
df
# Out:
#    ten  one
# 0   10    1
# 1   20   -2
# 2   30   -4
# 3   40    5
# 4   50    6

# %%
for i in range(len(df)):
    if df.iloc[i,1] <0:
        df.iloc[i,1] =0
df
# Out:
#    ten  one
# 0   10    1
# 1   20    0
# 2   30    0
# 3   40    5
# 4   50    6

# %%
def relu(value):
    if value<0:
        value = 0
    # else:
    #     value =value
    return value

# %%
    sr1=df.one.apply(relu)
    sr1
# Out:
# 0    1
# 1    0
# 2    0
# 3    5
# 4    6
# Name: one, dtype: int64

# %%
sr1 = df.ten.apply(lambda x: x*3 -4)
sr1
# Out:
# 0     26
# 1     56
# 2     86
# 3    116
# 4    146
# Name: ten, dtype: int64

# %%
df1 =pd.DataFrame({'a':['a0','a1','a2','a3'],
                   'b':['b0','b1','b2','b3'],
                   'c':['c0','c1','c2','c3']},index=[0,1,2,3])
df1
df2 =pd.DataFrame({'a':['a2','a3','a4','a5'],
                   'b':['b2','b3','b4','b5'],
                   'c':['c2','c3','c4','c5'],
                   'd':['d2','d3','d4','d5']},index=[2,3,4,5])
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
result1=pd.concat([df1,df2])
#result1=pd.concat([df1,df2],ignore_index=)
result1.reset_index(drop=True,inplace=True)
result1
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 4  a2  b2  c2   d2
# 5  a3  b3  c3   d3
# 6  a4  b4  c4   d4
# 7  a5  b5  c5   d5

# %%
result2 = pd.concat([df1,df2],axis ='columns')
result2
# Out:
#      a    b    c    a    b    c    d
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5

# %%
result2 = pd.concat([df1,df2],axis ='columns', join='inner')#join='inner' --교집합 ,join='outter' -- 합집합
result2
# Out:
#     a   b   c   a   b   c   d
# 2  a2  b2  c2  a2  b2  c2  d2
# 3  a3  b3  c3  a3  b3  c3  d3

# %%
df= pd.read_csv('./datasets/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = df.loc[:,['Age','Sex','Pclass','Fare','Survived']]
df.head()
# Out:
#     Age     Sex  Pclass     Fare  Survived
# 0  22.0    male       3   7.2500         0
# 1  38.0  female       1  71.2833         1
# 2  26.0  female       3   7.9250         1
# 3  35.0  female       1  53.1000         1
# 4  35.0    male       3   8.0500         0

# %%
print(df['Pclass'].unique())
print(df['Pclass'].value_counts)
# Out:
# [3 1 2]
# <bound method IndexOpsMixin.value_counts of 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64>

# %%
grouped =df.groupby(['Pclass']) #그룹화작업
print(grouped)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7c91c49de830>

# %%
grouped_df ={}
for key,group in grouped:
    print('key',key)
    print('length',len(group))
    grouped_df[key]=group
    print(group.head())
# Out:
# key 1
# length 216
#      Age     Sex  Pclass     Fare  Survived
# 1   38.0  female       1  71.2833         1
# 3   35.0  female       1  53.1000         1
# 6   54.0    male       1  51.8625         0
# 11  58.0  female       1  26.5500         1
# 23  28.0    male       1  35.5000         1
# key 2
# length 184
#      Age     Sex  Pclass     Fare  Survived
# 9   14.0  female       2  30.0708         1
# 15  55.0  female       2  16.0000         1
# 17   NaN    male       2  13.0000         1
# 20  35.0    male       2  26.0000         0
# 21  34.0    male       2  13.0000         1
# key 3
# length 491
#     Age     Sex  Pclass     Fare  Survived
# 0  22.0    male       3   7.2500         0
# 2  26.0  female       3   7.9250         1
# 4  35.0    male       3   8.0500         0
# 5   NaN    male       3   8.4583         0
# 7   2.0    male       3  21.0750         0
# <ipython-input-69-76e196d52eff>:2: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key,group in grouped:

# %%
grouped_df.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
grouped_df[1]
# Out:
#       Age     Sex  Pclass     Fare  Survived
# 1    38.0  female       1  71.2833         1
# 3    35.0  female       1  53.1000         1
# 6    54.0    male       1  51.8625         0
# 11   58.0  female       1  26.5500         1
# 23   28.0    male       1  35.5000         1
# ..    ...     ...     ...      ...       ...
# 871  47.0  female       1  52.5542         1
# 872  33.0    male       1   5.0000         0
# 879  56.0  female       1  83.1583         1
# 887  19.0  female       1  30.0000         1
# 889  26.0    male       1  30.0000         1
#
# [216 rows x 5 columns]

# %%
average=grouped.mean()
average
# Out:
# <ipython-input-72-e5b52a4d756b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average=grouped.mean()
#               Age       Fare  Survived
# Pclass
# 1       38.233441  84.154687  0.629630
# 2       29.877630  20.662183  0.472826
# 3       25.140620  13.675550  0.242363

# %%
min=grouped.min()
min
# Out:
#          Age     Sex  Fare  Survived
# Pclass
# 1       0.92  female   0.0         0
# 2       0.67  female   0.0         0
# 3       0.42  female   0.0         0

# %%
max = grouped.max()
max
# Out:
#          Age   Sex      Fare  Survived
# Pclass
# 1       80.0  male  512.3292         1
# 2       70.0  male   73.5000         1
# 3       74.0  male   69.5500         1

# %%
grouped_two =df.groupby(['Pclass','Sex'])
for key,group in grouped_two:
    print('key',key)
    print('length',len(group))
    print(group.head())
# Out:
# key (1, 'female')
# length 94
#      Age     Sex  Pclass      Fare  Survived
# 1   38.0  female       1   71.2833         1
# 3   35.0  female       1   53.1000         1
# 11  58.0  female       1   26.5500         1
# 31   NaN  female       1  146.5208         1
# 52  49.0  female       1   76.7292         1
# key (1, 'male')
# length 122
#      Age   Sex  Pclass      Fare  Survived
# 6   54.0  male       1   51.8625         0
# 23  28.0  male       1   35.5000         1
# 27  19.0  male       1  263.0000         0
# 30  40.0  male       1   27.7208         0
# 34  28.0  male       1   82.1708         0
# key (2, 'female')
# length 76
#      Age     Sex  Pclass     Fare  Survived
# 9   14.0  female       2  30.0708         1
# 15  55.0  female       2  16.0000         1
# 41  27.0  female       2  21.0000         0
# 43   3.0  female       2  41.5792         1
# 53  29.0  female       2  26.0000         1
# key (2, 'male')
# length 108
#      Age   Sex  Pclass  Fare  Survived
# 17   NaN  male       2  13.0         1
# 20  35.0  male       2  26.0         0
# 21  34.0  male       2  13.0         1
# 33  66.0  male       2  10.5         0
# 70  32.0  male       2  10.5         0
# key (3, 'female')
# length 144
#      Age     Sex  Pclass     Fare  Survived
# 2   26.0  female       3   7.9250         1
# 8   27.0  female       3  11.1333         1
# 10   4.0  female       3  16.7000         1
# 14  14.0  female       3   7.8542         0
# 18  31.0  female       3  18.0000         0
# key (3, 'male')
# length 347
#      Age   Sex  Pclass     Fare  Survived
# 0   22.0  male       3   7.2500         0
# 4   35.0  male       3   8.0500         0
# 5    NaN  male       3   8.4583         0
# 7    2.0  male       3  21.0750         0
# 12  20.0  male       3   8.0500         0

# %%
grouped_two.mean()
# Out:
#                      Age        Fare  Survived
# Pclass Sex
# 1      female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# 2      female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# 3      female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
group3f = grouped_two.get_group((3,'female'))
group3f
# Out:
#       Age     Sex  Pclass     Fare  Survived
# 2    26.0  female       3   7.9250         1
# 8    27.0  female       3  11.1333         1
# 10    4.0  female       3  16.7000         1
# 14   14.0  female       3   7.8542         0
# 18   31.0  female       3  18.0000         0
# ..    ...     ...     ...      ...       ...
# 863   NaN  female       3  69.5500         0
# 875  15.0  female       3   7.2250         1
# 882  22.0  female       3  10.5167         0
# 885  39.0  female       3  29.1250         0
# 888   NaN  female       3  23.4500         0
#
# [144 rows x 5 columns]

# %%
dfg=grouped_two.mean()
print(type(dfg))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dfg.loc[(1,'male')]
# Out:
# Age         41.281386
# Fare        67.226127
# Survived     0.368852
# Name: (1, male), dtype: float64

# %%
dfg.loc[1]
# Out:
#               Age        Fare  Survived
# Sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %%
#dfg.loc[,'female'] #뒤에 있는 인덱스는 인덱싱되지않는다
dfg.xs('female',level='Sex') #xs를 써서 다음에 있는 것을 인덱싱
dfg.xs('male',level='Sex')
# Out:
#               Age       Fare  Survived
# Pclass
# 1       41.281386  67.226127  0.368852
# 2       30.740707  19.741782  0.157407
# 3       26.507589  12.661633  0.135447

# %%
#pdf1 = pd.pivot_table(df,index='Pclass',columns='Sex',values='Age',aggfunc='mean')
pdf1 = pd.pivot_table(df,index='Pclass',columns='Sex',values=['Age','Fare'],aggfunc='mean')
pdf1
# Out:
#               Age                   Fare
# Sex        female       male      female       male
# Pclass
# 1       34.611765  41.281386  106.125798  67.226127
# 2       28.722973  30.740707   21.970121  19.741782
# 3       21.750000  26.507589   16.118810  12.661633

# %%
pdf2 = pd.pivot_table(df,index='Pclass',columns='Sex',values='Age',aggfunc=['mean','sum','std'])
pdf2
# Out:
#              mean                sum                 std
# Sex        female       male  female     male     female       male
# Pclass
# 1       34.611765  41.281386  2942.0  4169.42  13.612052  15.139570
# 2       28.722973  30.740707  2125.5  3043.33  12.872702  14.793894
# 3       21.750000  26.507589  2218.5  6706.42  12.729964  12.159514

# %%
pdf3 = pd.pivot_table(df,index='Pclass',columns='Sex',values='Survived',aggfunc='mean')
pdf3
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
pdf4 =pd.pivot_table(df,index=['Pclass','Sex'],columns='Survived',values=['Age','Fare'],aggfunc=['mean','max'])
pdf4
# Out:
#                     mean                                      max        \
#                      Age                   Fare               Age
# Survived               0          1           0           1     0     1
# Pclass Sex
# 1      female  25.666667  34.939024  110.604167  105.978159  50.0  63.0
#        male    44.581967  36.248000   62.894910   74.637320  71.0  80.0
# 2      female  36.000000  28.080882   18.250000   22.288989  57.0  55.0
#        male    33.369048  16.022000   19.488965   21.095100  70.0  62.0
# 3      female  23.818182  19.329787   19.773093   12.464526  48.0  63.0
#        male    27.255814  22.274211   12.204469   15.579696  74.0  45.0
#
#
#                  Fare
# Survived            0         1
# Pclass Sex
# 1      female  151.55  512.3292
#        male    263.00  512.3292
# 2      female   26.00   65.0000
#        male     73.50   39.0000
# 3      female   69.55   31.3875
#        male     69.55   56.4958

# %%
print(pdf4.index)
# Out:
# [MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['Pclass', 'Sex'])]

# %%
print(pdf4.columns)
# Out:
# MultiIndex([('mean',  'Age', 0),
#             ('mean',  'Age', 1),
#             ('mean', 'Fare', 0),
#             ('mean', 'Fare', 1),
#             ( 'max',  'Age', 0),
#             ( 'max',  'Age', 1),
#             ( 'max', 'Fare', 0),
#             ( 'max', 'Fare', 1)],
#            names=[None, None, 'Survived'])

# %%
df
# Out:
#       Age     Sex  Pclass     Fare  Survived
# 0    22.0    male       3   7.2500         0
# 1    38.0  female       1  71.2833         1
# 2    26.0  female       3   7.9250         1
# 3    35.0  female       1  53.1000         1
# 4    35.0    male       3   8.0500         0
# ..    ...     ...     ...      ...       ...
# 886  27.0    male       2  13.0000         0
# 887  19.0  female       1  30.0000         1
# 888   NaN  female       3  23.4500         0
# 889  26.0    male       1  30.0000         1
# 890  32.0    male       3   7.7500         0
#
# [891 rows x 5 columns]

# %%
df_teenage=df.loc[(df.Age>=10) & (df.Age<20)] #비트연산해야함
df_teenage.head()
# Out:
#      Age     Sex  Pclass      Fare  Survived
# 9   14.0  female       2   30.0708         1
# 14  14.0  female       3    7.8542         0
# 22  15.0  female       3    8.0292         1
# 27  19.0    male       1  263.0000         0
# 38  18.0  female       3   18.0000         0

# %%
df_teenage['Survived'].sum()
df_teenage['Survived'].mean()
# Out:
# 0.4019607843137255

# %%
df.Survived.mean()
# Out:
# 0.3838383838383838

# %%
df_child = df.loc[df.Age<10]
df_child['Survived'].mean()
# Out:
# 0.6129032258064516

# %%
df_old = df.loc[df.Age>=60]
df_old.Survived.mean()
# Out:
# 0.2692307692307692

# %%
df_female_child =df.loc[(df.Age<10) & (df.Sex =='female')]
df_female_child.head()
# Out:
#      Age     Sex  Pclass     Fare  Survived
# 10   4.0  female       3  16.7000         1
# 24   8.0  female       3  21.0750         0
# 43   3.0  female       2  41.5792         1
# 58   5.0  female       2  27.7500         1
# 119  2.0  female       3  31.2750         0

# %%
df_female_child.mean()
# Out:
# <ipython-input-108-5f1bda19bb4c>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_female_child.mean()
# Age          4.416667
# Pclass       2.666667
# Fare        27.972637
# Survived     0.633333
# dtype: float64

# %%
titanic =pd.read_csv('./datasets/titanic.csv')
isin_filter = titanic['SibSp'].isin([2,4,5])
isin_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: SibSp, Length: 891, dtype: bool

# %%
df_isin = titanic[isin_filter]
df_isin.head()
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 16           17         0       3                Rice, Master. Eugene    male
# 38           39         0       3  Vander Planke, Miss. Augusta Maria  female
# 48           49         0       3                 Samaan, Mr. Youssef    male
# 50           51         0       3          Panula, Master. Juha Niilo    male
# 59           60         0       3  Goodwin, Master. William Frederick    male
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 16   2.0      4      1   382652  29.1250   NaN        Q
# 38  18.0      2      0   345764  18.0000   NaN        S
# 48   NaN      2      0     2662  21.6792   NaN        C
# 50   7.0      4      1  3101295  39.6875   NaN        S
# 59  11.0      5      2  CA 2144  46.9000   NaN        S

# %%
df_sibsp245 = titanic[(titanic.SibSp ==2)|(titanic.SibSp ==4)|(titanic.SibSp ==5)]
df_sibsp245.head()
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 16           17         0       3                Rice, Master. Eugene    male
# 38           39         0       3  Vander Planke, Miss. Augusta Maria  female
# 48           49         0       3                 Samaan, Mr. Youssef    male
# 50           51         0       3          Panula, Master. Juha Niilo    male
# 59           60         0       3  Goodwin, Master. William Frederick    male
#
#      Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 16   2.0      4      1   382652  29.1250   NaN        Q
# 38  18.0      2      0   345764  18.0000   NaN        S
# 48   NaN      2      0     2662  21.6792   NaN        C
# 50   7.0      4      1  3101295  39.6875   NaN        S
# 59  11.0      5      2  CA 2144  46.9000   NaN        S

# %%
df_man=df.loc[(df.Age<30) & (df.Sex =='male') &(df.Age>=20)]
df_man.Survived.mean()
# Out:
# 0.16891891891891891
