# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
raw_data = sns.load_dataset('titanic')
raw_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
raw_data.isnull().sum() #isnull인지 확인
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
clean_data=raw_data.dropna(axis=1,thresh=500) #deck삭제할 작업 thresh - 500개 기준 , axis컴럼 1개삭제

# %%
clean_data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
mean_age=clean_data['age'].mean() #나이 빈값에 평균을 넣을 작업
print(mean_age)
# Out:
# 29.69911764705882

# %%
#clean_data = clean_data['age'].fillna(mean_age) 이건 삭제된 컬럼을 clean_data에 저장
clean_data['age'].fillna(mean_age,inplace=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10384\3771746482.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['age'].fillna(mean_age,inplace=True)

# %%
clean_data.head(10)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0         0       3    male  22.000000      1      0   7.2500        S
# 1         1       1  female  38.000000      1      0  71.2833        C
# 2         1       3  female  26.000000      0      0   7.9250        S
# 3         1       1  female  35.000000      1      0  53.1000        S
# 4         0       3    male  35.000000      0      0   8.0500        S
# 5         0       3    male  29.699118      0      0   8.4583        Q
# 6         0       1    male  54.000000      0      0  51.8625        S
# 7         0       3    male   2.000000      3      1  21.0750        S
# 8         1       3  female  27.000000      0      2  11.1333        S
# 9         1       2  female  14.000000      1      0  30.0708        C
#
#     class    who  adult_male  alone
# 0   Third    man        True  False
# 1   First  woman       False  False
# 2   Third  woman       False   True
# 3   First  woman       False  False
# 4   Third    man        True   True
# 5   Third    man        True   True
# 6   First    man        True   True
# 7   Third  child       False  False
# 8   Third  woman       False  False
# 9  Second  child       False  False

# %%
clean_data.drop(['embark_town','alive'], axis=1, inplace=True) #컴럼 삭제하기
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10384\856110939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data.drop(['embark_town','alive'], axis=1, inplace=True)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    889 non-null    object
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(3)
# memory usage: 65.5+ KB

# %%
clean_data['embarked'].fillna(method='ffill',inplace=True) #정착지 바꾸기 작업
clean_data['embarked'][825:830]
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_10384\879758010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['embarked'].fillna(method='ffill',inplace=True)
# 825    Q
# 826    S
# 827    C
# 828    Q
# 829    Q
# Name: embarked, dtype: object

# %%
clean_data.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# alone         0
# dtype: int64

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    object
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(3)
# memory usage: 65.5+ KB

# %%
clean_data['sex'].replace({'male':0 ,'female':1} , inplace=True)
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    int64
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    object
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(5), object(2)
# memory usage: 65.5+ KB
# C:\Users\PC\AppData\Local\Temp\ipykernel_10384\3487155171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['sex'].replace({'male':0 ,'female':1} , inplace=True)

# %%
print(clean_data['sex'].unique()) #unique는 가진것만 보여줌
# Out:
# [0 1]

# %%
print(clean_data['embarked'].unique())
# Out:
# ['S' 'C' 'Q']

# %%
from sklearn import preprocessing

# %%
label_encoder= preprocessing.LabelEncoder()
onehot_encoder = preprocessing.OneHotEncoder()

# %%
print(clean_data['embarked'].value_counts())
# Out:
# embarked
# S    644
# C    169
# Q     78
# Name: count, dtype: int64

# %%
clean_data['embarked'] = label_encoder.fit_transform(clean_data['embarked'])
print(clean_data['embarked'].unique())
# Out:
# [2 0 1]
# C:\Users\PC\AppData\Local\Temp\ipykernel_10384\650277197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['embarked'] = label_encoder.fit_transform(clean_data['embarked'])

# %%
print(clean_data['embarked'].value_counts())
# Out:
# embarked
# 2    644
# 0    169
# 1     78
# Name: count, dtype: int64

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    int64
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    int32
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    bool
#  11  alone       891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int32(1), int64(5), object(1)
# memory usage: 62.0+ KB

# %%
clean_data['adult_male']=clean_data['adult_male'].astype('int64')
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    891 non-null    int64
#  1   pclass      891 non-null    int64
#  2   sex         891 non-null    int64
#  3   age         891 non-null    float64
#  4   sibsp       891 non-null    int64
#  5   parch       891 non-null    int64
#  6   fare        891 non-null    float64
#  7   embarked    891 non-null    int32
#  8   class       891 non-null    category
#  9   who         891 non-null    object
#  10  adult_male  891 non-null    int64
#  11  alone       891 non-null    bool
# dtypes: bool(1), category(1), float64(2), int32(1), int64(6), object(1)
# memory usage: 68.1+ KB
# C:\Users\PC\AppData\Local\Temp\ipykernel_10384\3392618362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data['adult_male']=clean_data['adult_male'].astype('int64')

# %%
clean_data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500         2  Third    man
# 1         1       1    1  38.0      1      0  71.2833         0  First  woman
# 2         1       3    1  26.0      0      0   7.9250         2  Third  woman
# 3         1       1    1  35.0      1      0  53.1000         2  First  woman
# 4         0       3    0  35.0      0      0   8.0500         2  Third    man
#
#    adult_male  alone
# 0           1  False
# 1           0  False
# 2           0   True
# 3           0  False
# 4           1   True

# %%
target = clean_data[['survived']] #산 사람만 빼어놓음
target
# Out:
#      survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
training_data = clean_data.drop('survived' ,axis=1 ,inplace=False) #나머지 데이터
training_data.head()
# Out:
#    pclass  sex   age  sibsp  parch     fare  embarked  class    who  \
# 0       3    0  22.0      1      0   7.2500         2  Third    man
# 1       1    1  38.0      1      0  71.2833         0  First  woman
# 2       3    1  26.0      0      0   7.9250         2  Third  woman
# 3       1    1  35.0      1      0  53.1000         2  First  woman
# 4       3    0  35.0      0      0   8.0500         2  Third    man
#
#    adult_male  alone
# 0           1  False
# 1           0  False
# 2           0   True
# 3           0  False
# 4           1   True

# %%
value_data = training_data[['age','fare']] #수를 가진 데이터를 정규화
value_data
# Out:
#            age     fare
# 0    22.000000   7.2500
# 1    38.000000  71.2833
# 2    26.000000   7.9250
# 3    35.000000  53.1000
# 4    35.000000   8.0500
# ..         ...      ...
# 886  27.000000  13.0000
# 887  19.000000  30.0000
# 888  29.699118  23.4500
# 889  26.000000  30.0000
# 890  32.000000   7.7500
#
# [891 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler #정규화작업
scaler = StandardScaler()
scaled_data = scaler.fit_transform(value_data)
value_data = pd.DataFrame(scaled_data,columns=value_data.columns)
value_data.head()
# Out:
#         age      fare
# 0 -0.592481 -0.502445
# 1  0.638789  0.786845
# 2 -0.284663 -0.488854
# 3  0.407926  0.420730
# 4  0.407926 -0.486337

# %%
training_data.drop(['age','fare'] ,axis=1,inplace=True) #value로 뺏으니 삭제함
training_data.head()
# Out:
#    pclass  sex  sibsp  parch  embarked  class    who  adult_male  alone
# 0       3    0      1      0         2  Third    man           1  False
# 1       1    1      1      0         0  First  woman           0  False
# 2       3    1      0      0         2  Third  woman           0   True
# 3       1    1      1      0         2  First  woman           0  False
# 4       3    0      0      0         2  Third    man           1   True

# %%
onehot_data=pd.get_dummies(training_data['pclass']) #onehot엔코딩   가변수화
onehot_data.head()
# Out:
#        1      2      3
# 0  False  False   True
# 1   True  False  False
# 2  False  False   True
# 3   True  False  False
# 4  False  False   True

# %%
onehot_data = pd.get_dummies(training_data ,columns=training_data.columns) #onehotencoding
onehot_data.head()
# Out:
#    pclass_1  pclass_2  pclass_3  sex_0  sex_1  sibsp_0  sibsp_1  sibsp_2  \
# 0     False     False      True   True  False    False     True    False
# 1      True     False     False  False   True    False     True    False
# 2     False     False      True  False   True     True    False    False
# 3      True     False     False  False   True    False     True    False
# 4     False     False      True   True  False     True    False    False
#
#    sibsp_3  sibsp_4  ...  class_First  class_Second  class_Third  who_child  \
# 0    False    False  ...        False         False         True      False
# 1    False    False  ...         True         False        False      False
# 2    False    False  ...        False         False         True      False
# 3    False    False  ...         True         False        False      False
# 4    False    False  ...        False         False         True      False
#
#    who_man  who_woman  adult_male_0  adult_male_1  alone_False  alone_True
# 0     True      False         False          True         True       False
# 1    False       True          True         False         True       False
# 2    False       True          True         False        False        True
# 3    False       True          True         False         True       False
# 4     True      False         False          True        False        True
#
# [5 rows x 32 columns]

# %%
onehot_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 32 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pclass_1      891 non-null    bool
#  1   pclass_2      891 non-null    bool
#  2   pclass_3      891 non-null    bool
#  3   sex_0         891 non-null    bool
#  4   sex_1         891 non-null    bool
#  5   sibsp_0       891 non-null    bool
#  6   sibsp_1       891 non-null    bool
#  7   sibsp_2       891 non-null    bool
#  8   sibsp_3       891 non-null    bool
#  9   sibsp_4       891 non-null    bool
#  10  sibsp_5       891 non-null    bool
#  11  sibsp_8       891 non-null    bool
#  12  parch_0       891 non-null    bool
#  13  parch_1       891 non-null    bool
#  14  parch_2       891 non-null    bool
#  15  parch_3       891 non-null    bool
#  16  parch_4       891 non-null    bool
#  17  parch_5       891 non-null    bool
#  18  parch_6       891 non-null    bool
#  19  embarked_0    891 non-null    bool
#  20  embarked_1    891 non-null    bool
#  21  embarked_2    891 non-null    bool
#  22  class_First   891 non-null    bool
#  23  class_Second  891 non-null    bool
#  24  class_Third   891 non-null    bool
#  25  who_child     891 non-null    bool
#  26  who_man       891 non-null    bool
#  27  who_woman     891 non-null    bool
#  28  adult_male_0  891 non-null    bool
#  29  adult_male_1  891 non-null    bool
#  30  alone_False   891 non-null    bool
#  31  alone_True    891 non-null    bool
# dtypes: bool(32)
# memory usage: 28.0 KB

# %%
training_data = pd.concat([value_data,onehot_data] ,axis=1)
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 34 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           891 non-null    float64
#  1   fare          891 non-null    float64
#  2   pclass_1      891 non-null    bool
#  3   pclass_2      891 non-null    bool
#  4   pclass_3      891 non-null    bool
#  5   sex_0         891 non-null    bool
#  6   sex_1         891 non-null    bool
#  7   sibsp_0       891 non-null    bool
#  8   sibsp_1       891 non-null    bool
#  9   sibsp_2       891 non-null    bool
#  10  sibsp_3       891 non-null    bool
#  11  sibsp_4       891 non-null    bool
#  12  sibsp_5       891 non-null    bool
#  13  sibsp_8       891 non-null    bool
#  14  parch_0       891 non-null    bool
#  15  parch_1       891 non-null    bool
#  16  parch_2       891 non-null    bool
#  17  parch_3       891 non-null    bool
#  18  parch_4       891 non-null    bool
#  19  parch_5       891 non-null    bool
#  20  parch_6       891 non-null    bool
#  21  embarked_0    891 non-null    bool
#  22  embarked_1    891 non-null    bool
#  23  embarked_2    891 non-null    bool
#  24  class_First   891 non-null    bool
#  25  class_Second  891 non-null    bool
#  26  class_Third   891 non-null    bool
#  27  who_child     891 non-null    bool
#  28  who_man       891 non-null    bool
#  29  who_woman     891 non-null    bool
#  30  adult_male_0  891 non-null    bool
#  31  adult_male_1  891 non-null    bool
#  32  alone_False   891 non-null    bool
#  33  alone_True    891 non-null    bool
# dtypes: bool(32), float64(2)
# memory usage: 41.9 KB

# %%
training_data=training_data.astype('float64')

# %%
from sklearn.model_selection import train_test_split #학습시켜보자
x_train,x_test,y_train,y_test=train_test_split(training_data,target,test_size=0.20)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (712, 34) (712, 1)
# (179, 34) (179, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model = Sequential()
model.add(Dense(128,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(32,input_dim=34,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,input_dim=34,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 128)               4480
#
#  dropout_35 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 256)               33024
#
#  dropout_36 (Dropout)        (None, 256)               0
#
#  dense_42 (Dense)            (None, 512)               131584
#
#  dropout_37 (Dropout)        (None, 512)               0
#
#  dense_43 (Dense)            (None, 256)               131328
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  dense_44 (Dense)            (None, 128)               32896
#
#  dropout_39 (Dropout)        (None, 128)               0
#
#  dense_45 (Dense)            (None, 64)                8256
#
#  dropout_40 (Dropout)        (None, 64)                0
#
#  dense_46 (Dense)            (None, 32)                2080
#
#  dropout_41 (Dropout)        (None, 32)                0
#
#  dense_47 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 343681 (1.31 MB)
# Trainable params: 343681 (1.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mse',optimizer='adam',metrics=['binary_accuracy'])

# %%
fit_hist=model.fit(x_train,y_train,batch_size=50,epochs=5,validation_split=0.2,verbose=1)
# Out:
# Epoch 1/5
# 12/12 [==============================] - 2s 26ms/step - loss: 0.2369 - binary_accuracy: 0.6098 - val_loss: 0.1709 - val_binary_accuracy: 0.8531
# Epoch 2/5
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1737 - binary_accuracy: 0.7434 - val_loss: 0.1215 - val_binary_accuracy: 0.8392
# Epoch 3/5
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1553 - binary_accuracy: 0.7926 - val_loss: 0.1227 - val_binary_accuracy: 0.8462
# Epoch 4/5
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1503 - binary_accuracy: 0.7961 - val_loss: 0.1298 - val_binary_accuracy: 0.8322
# Epoch 5/5
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1324 - binary_accuracy: 0.8102 - val_loss: 0.1215 - val_binary_accuracy: 0.8531

# %%
import matplotlib.pyplot as plt
plt.plot(fit_hist.history['binary_accuracy'])
plt.plot(fit_hist.history['val_binary_accuracy'])
plt.show()

# %%
score = model.evaluate(x_test,y_test,verbose=0)
print('loss',score[0])
print('accuracy',score[1])
# Out:
# loss 0.12968270480632782
# accuracy 0.826815664768219
